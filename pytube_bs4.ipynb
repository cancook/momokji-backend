# %%
import requests
from bs4 import BeautifulSoup

from pytube import Playlist


class Pytube:
    def __init__(self):
        self.headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3497.100 Safari/537.36' }

        self.paik_jongwon_url = "https://www.youtube.com/watch?v=87zznFb0-us&list=PLoABXt5mipg6mIdGKBuJlv5tmQFAQ3OYr"
        self.paik_jongwon_ytpl = Playlist(self.paik_jongwon_url)
        self.paik_jongwon_ytpl_list = self.paik_jongwon_ytpl.video_urls._elements # Playlist의 동영상 urls

    def crawler(self):
        print(self.paik_jongwon_ytpl)
        for url in self.paik_jongwon_ytpl_list:
            response = requests.get(url=url, headers=self.headers)
            html = response.text
            soup = BeautifulSoup(html, 'html.parser')
            bs = soup.find_all('script')
            print(bs)

        # print(len(self.paik_jongwon_ytpl.video_urls._elements))
        # for yt in self.paik_jongwon_ytpl.video_urls._elements:
        #     res = requests.get(yt)
        #     print(res)
        #     print('===')
            
        

pytube = Pytube()
pytube.crawler()
# Out:
# ['https://www.youtube.com/watch?v=87zznFb0-us', 'https://www.youtube.com/watch?v=LojVJnvLb30', 'https://www.youtube.com/watch?v=JvuV9aAh7VY', 'https://www.youtube.com/watch?v=w9ML-v8OG1Y', 'https://www.youtube.com/watch?v=SILoOGBiAyA', 'https://www.youtube.com/watch?v=-MvfUUPB5-Y', 'https://www.youtube.com/watch?v=Zkxiydlmplw', 'https://www.youtube.com/watch?v=ZuO-VnWMrno', 'https://www.youtube.com/watch?v=YLd78Yqoy9I', 'https://www.youtube.com/watch?v=JrTVWvj8uhs', 'https://www.youtube.com/watch?v=fpqJOFMfhmk', 'https://www.youtube.com/watch?v=RmZyxKOUbfs', 'https://www.youtube.com/watch?v=-Imo0xgUQG0', 'https://www.youtube.com/watch?v=e--h7ax_6pQ', 'https://www.youtube.com/watch?v=uu8BqXy6lf4', 'https://www.youtube.com/watch?v=Mfnwc1dc0MY', 'https://www.youtube.com/watch?v=SeUG8iRDE_g', 'https://www.youtube.com/watch?v=rLDquEv-ZJg', 'https://www.youtube.com/watch?v=p7HGmwiuuvE', 'https://www.youtube.com/watch?v=6lcrq5D_63o', 'https://www.youtube.com/watch?v=u1m21zlfVLo', 'https://w
# ...
